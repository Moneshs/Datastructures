# %%
def mergesort(arr):
    if len(arr)>1:
        mid=len(arr)//2
        L=arr[mid:]
        R=arr[:mid]
        
        mergesort(L)
        mergesort(R)
        
        i=j=k=0
        while i<len(L) and j<len(R):
            if L[i]<R[j]:
                arr[k]=L[i]
                i+=1
            else:
                arr[k]=R[j]
                j+=1
            k+=1
        while i<len(L):
            arr[k]=L[i]
            i+=1
            k+=1
        while j<len(R):
            arr[k]=R[j]
            j+=1
            k+=1

def printlist(arr):
    for i in range(len(arr)):
        print(arr[i],end=' ')
    print()
    
arr=[97,47,46,1,15,24,36,88,76,67]
mergesort(arr)
printlist(arr)
# Out:
# 1 15 24 36 46 47 67 76 88 97

# %%
def insertionsort(arr1):
    n=len(arr)
    for i in range(1,n):
        key=arr1[i]
        j=i-1
        while j>=0 and key <arr1[j]:
            arr1[j+1],arr1[j]=arr1[j],arr1[j+1]
            j-=1
            arr[j+1]=key
            
#def printlist(arr1):
    
    
arr1=[97,47,46,1,15,24,36,88,76,67]
insertionsort(arr1)
#printlist(arr1)
for i in range(len(arr1)):
        print("%d"%arr1[i])
# Out:
# 1
# 15
# 24
# 36
# 46
# 47
# 67
# 76
# 88
# 97

# %%
def bubblesort(arr2):
    n=len(arr2)
    for i in range(n):
        for j in range (0,n-i-1):
            if arr2[j]>arr2[j+1]:
                arr2[j+1],arr2[j]=arr2[j],arr2[j+1]
                
arr2=[97,47,46,1,15,24,36,88,76,67]
bubblesort(arr2)
for i in range(len(arr2)):
    print("%d"%arr2[i])
# Out:
# 1
# 15
# 24
# 36
# 46
# 47
# 67
# 76
# 88
# 97

# %%
class Node:
    def __init__(self,data):
        self.item=data
        self.ref=None
lis=[]
class Linkedlist:
    def __init__(self):
        self.start_node=None

    def traverse_list(self):
        if self.start_node is None:
            print("List is empty")
            return
        else:
            n=self.start_node
            while n is not None:
                print(n.item,end=" "),
                lis.append(n.item)
                n=n.ref
            #print()

    def insert_begin(self,data):
        new_node=Node(data)
        new_node.ref=self.start_node
        self.start_node=new_node

    def insert_end(self,data):
        new_node=Node(data)
        if self.start_node is None:
            self.start_node=new_node
            return
        n=self.start_node
        while n.ref is not None:
            n=n.ref
        n.ref=new_node;
    def search_item(self,data):
        if self.start_node is None:
            print("List is empty")
            return
        n=self.start_node
        while n is not None:
            if n.item==data:
                new_linked_list.delete_item(data)
                return
            n=n.ref
            
        else:
            new_linked_list.insert_end(data)
            return
    
    def delete_item(self,data):
        if self.start_node is None:
            print("no element to delete")
            return
        if self.start_node.item==data:
            self.start_node=self.start_node.ref
            return
        n=self.start_node
        while n.ref is not None:
            if n.ref.item==data:
                break
            n=n.ref
            
        if n.ref is None:
            print("item not found in the list")
            #new_linked_list.insert_end(data)
        else:
            n.ref=n.ref.ref
                 
new_linked_list = Linkedlist()
with open('words.txt','r') as f:
    for line in f:
        for word in line.split():
            new_linked_list.insert_end(word)
#print("Before searching item:")             
#new_linked_list.traverse_list()
new_linked_list.search_item('and')
new_linked_list.search_item('a')
print("\nAfter searching item in linkedlist:")
new_linked_list.traverse_list()

with open("file.txt", "a") as output:
    for listitem in lis:
        output.write('%s '%listitem)
# Out:
# After searching item in linkedlist:
# single distinct meaningful element of speech or writing, used with others (or sometimes alone) to form a sentence and

# %%
class Node:
    def __init__(self, data):
        self.data = int(data)
        self.next = None
        
        
list1=[]
class LinkedList:
    def __init__(self):
        self.head = None    

    def asc_ordered_list(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            return

        temp = self.head
        if temp.data > data:
            new_node.next = temp
            self.head = new_node
            return

        while temp.next:
            if temp.next.data > data:
                break
            temp = temp.next

        new_node.next = temp.next
        temp.next = new_node

   

    def display_list(self):
        temp = self.head
        while temp is not None:
            print("data = {0}".format(temp.data))
            list1.append(temp.data)
            temp = temp.next
            
    def search_item(self,data):
        if self.head is None:
            print("List is empty")
            return
        n=self.head
        while n is not None:
            if n.data==data:
                #print("found")
                new_list.delete_item(data)
                return
            n=n.next
            
        else:
            #print("not found")
            new_list.asc_ordered_list(data)
            return
        
    def delete_item(self,data):
        if self.head is None:
            print("no element to delete")
            return
        if self.head.data==data:
            self.head=self.head.next
            return
        n=self.head
        while n.next is not None:
            if n.next.data==data:
                break
            n=n.next
            
        if n.next is None:
            print("item not found in the list")
            #new_linked_list.insert_end(data)
        else:
            n.next=n.next.next

new_list=LinkedList()
with open("numbers.txt", 'r') as num:
    for line in num:
        for word in line.split():
            a=int(word)
            #print(type(a))
            new_list.asc_ordered_list(a)
#new_list.display_list()
new_list.search_item(122)
#new_list.display_list()
new_list.search_item(1)
new_list.display_list()

with open("numbers1.txt", "a") as f:
    for listitem1 in list1:
        f.write('%s '%listitem1)
# Out:
# data = 3
# data = 12
# data = 14
# data = 23
# data = 34
# data = 47
# data = 122

# %%
openlist=['(','{','[']
closelist=[')','}',']']

def balanced(str):
    stack=[]
    for i in str:
        if i in openlist:
            stack.append(i)
        elif i in closelist:
            pos=closelist.index(i)
            if ((len(stack)>0)and (openlist[pos]==stack[(len(st):ack)-1)])):
                stack.pop()
            else:
                return "unbalanced"
                     
    if len(stack)==0:
         return "balance parenthesis"
    


string = "(5+6)∗(7+8)/(4+3)(5+6)∗(7+8)/(4+3)"
#balanced(string) 
print(balanced(string))
string="(5+6)∗(7+8)/(4+3)(5+6)∗(7+8)/(4+3)}"
print(balanced(string))
# Out:
# balance parenthesis
# unbalanced

# %%
#Amount=1000):
class queue:
    def __init__(self,balance):
        self.queue=[]
        self.balance=1000
        
          
    def enqueue_deposit(self,data):
        self.queue.append(data)
        #print(self.queue)
        print(self.balance)
        deposit=int(input("enter the amount to deposit:"))
        self.balance+=deposit
        print(self.balance)
        
        
    def enqueue_withdraw(self,data):
        self.queue.append(data)
        #print(self.queue)
        withdraw=int(input("enter the amount to withdraw:"))
        if self.balance>=withdraw: 
                self.balance-=withdraw
        else:
            print("insuffient balance")
        
    def dequeue(self):
        self.queue.pop(0)        

    def display(self):
        print(self.balance)
    def size(self):
        s=len(self.queue)
        if s==0:
            print("queue is empty")
        else:
            print("queue length is",s)
            
queue1=queue('100')
queue1.enqueue_withdraw('a')
queue1.enqueue_deposit('b')
queue1.dequeue()
queue1.enqueue_withdraw('c')
queue1.dequeue()
queue1.enqueue_deposit('d')
queue1.dequeue()
#queue1.display()
queue1.dequeue()
queue1.size()
# Out:
# enter the amount to withdraw:100
# 900
# enter the amount to deposit:400
# 1300
# enter the amount to withdraw:500
# 800
# enter the amount to deposit:1000
# 1800
# queue is empty

# %%
class Deque:
    def __init__(self):
        self.items = []

    def isEmpty(self):
        return self.items == []

    def addFront(self, item):
        self.items.append(item)

    def rear_insert(self, item):
        self.items.insert(0,item)

    def delete_Front(self):
        return self.items.pop()

    def delete_Rear(self):
        return self.items.pop(0)

    def size(self):
        return len(self.items)  
    
def palindrome(string):
    p=Deque()
    for ch in string:
        p.rear_insert(ch)
        
    result=True
    
    while p.size()>1 and result:
        first=p.delete_Front()
        last=p.delete_Rear()
        
        if(first!=last):
            result=False
    return result

print(palindrome("radar"))
print(palindrome("abc"))
# Out:
# True
# False
